# %% [markdown]
# # Tipos de imports

# %%
import numpy as np

# %%
# pip freeze  # mostrar versoes de bibliotecas intaladas

# %%
a = [1,2,3,4,5]

# %%
type(a)
# Out:
# list

# %%
b = np.array([1,2,3,4,5])

# %%
b
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(b)
# Out:
# numpy.ndarray

# %% [markdown]
# Tipos 2 de import

# %%
from numpy import *

# %%
array([3,4,5])
# Out:
# array([3, 4, 5])

# %%
pi
# Out:
# 3.141592653589793

# %%
cos(0)
# Out:
# 1.0

# %% [markdown]
# ## Nomenclatura
#
# * Vetores
#
# * Matrizes
#
# Arrays
